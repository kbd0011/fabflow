# %% [markdown]
# # 00 · FabFlow-Cortex overview\n\nA SimPy wafer-fab digital twin + DuckDB analytics + a pre/post improvement study.\n\nThese notebooks assume the package is installed (`bash setup_fabflow.sh`) and are run from the repo root.\n\nPipeline: **synthetic fab → simulate → DuckDB star schema → KPIs → improvement study → report/dashboard/BI**.\n\n- `01_explore_fab_spec` — look at the generated fab (work centers, routes, static load).\n- `02_run_study_and_compare` — run the scenarios and quantify the improvement.\n- `03_dashboard_preview` — preview the dashboard charts inline.

# %%
from fabflow.config import load_config\ncfg = load_config('../configs/config.yaml')\nprint('scenarios:', list(cfg.scenarios))\nprint('CONWIP level:', cfg.sim.conwip_level, '| reps:', cfg.sim.reps)\nprint('horizon (h):', cfg.sim.horizon_hours, '| warmup (h):', cfg.sim.warmup_hours)
